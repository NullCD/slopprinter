# %% [markdown]
# ### Launcher
# **Default arguments:** = `--xformers --cuda-stream --persistent-patches`
#
# Add `--N=ngrok_token` to start NGROK tunnel<br>
# Add `--Z=zrok_token` to start ZROK tunnel

# %%
# %cd -q $WebUI
# %run segsmaker.py --xformers --cuda-stream --persistent-patches

# %% [markdown]
# ### WebUI Installer
# Please get your **CivitAI API key** in CivitAI page under Settings.
# For the fork to work, please use Forge-Classic only. Other WebUIs are not guaranteed to work 100%.

# %%
webui = 'Forge-Classic'
civitai_key = ''
hf_read_token = ''

# !wget -qO /kaggle/setup.py https://github.com/NullCD/segsmaker-custom/raw/main/script/KC/setup.py
# %run /kaggle/setup.py --webui="$webui" --civitai_key="$civitai_key" --hf_read_token="$hf_read_token"

# %% [markdown]
# ### Models/LoRAS Downloader
# These are commands with empty inputs. If you have any needs to install something, just put the download link next to the commands. Otherwise, leave it alone. (Checkpoint and LoRA section inputs are examples.)

# %%
# --- Checkpoint ---
# %cd -q $CKPT
# %download https://civitai.com/models/964011?modelVersionId=1837143

# --- LoRA ---
# %cd -q $LORA
# %download https://civitai.com/models/1035403/wolf-con-f-artist-style-or-ilxl
# %download https://civitai.com/models/1562510?modelVersionId=2521543

# --- ADetailer ---
# !mkdir /kaggle/working/Forge-Classic/models/adetailer
# %cd -q /kaggle/working/Forge-Classic/models/adetailer
# !wget -O AnzhcFace-seg640-v4-y11n.pt "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Face%20seg%20640%20v4%20y11n.pt"

# --- SD Extensions / ComfyUI Custom Nodes ---
# %cd -q $Extensions
# !git clone URL

# --- VAE ---
# %cd -q $VAE
# %download

# --- Embeddings ---
## %cd -q $Embeddings
## %download

# --- Upscalers ---
## %cd -q $Upscalers
## %download

# --- FLUX Unet ---
## %cd -q $UNET
## %download

# --- FLUX Clip ---
## %cd -q $CLIP
## %download

# %%
# --- Controlnet ---
# %run $Controlnet_Widget

# %% [markdown]
# (Temporary folders, suitable if you are low on storage.)

# %%
# --- TMP Checkpoint ---
## %cd -q $TMP_CKPT
## %download https://civitai.com/api/download/models/357609

# --- TMP LoRA ---
## %cd -q $TMP_LORA
## %download https://huggingface.co/Linaqruf/style-enhancer-xl-lora/resolve/main/style-enhancer-xl.safetensors
